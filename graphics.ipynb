# %%
# Importar librerias
import pandas
import matplotlib.pyplot as plt

# %%
# Lectura del csv
df = pandas.read_csv('distances.csv')

# %%
# Graficación de histogramas

for col in df.columns[:-1]:

  data = df[col].dropna()
  
  data_min, data_max = min(data), max(data)
  bin_width = (data_max - data_min) / 10

  plt.figure(figsize=(8, 6))

  plt.hist(data, bins=10, range=(data_min, data_max + bin_width), color='cyan', edgecolor='black')

  plt.title(f'Histograma de las distancias entre puntos con dimension {col}')
  plt.xlabel('Distancia')
  plt.ylabel('Frecuencia')
  
  plt.xlim(0)
  
  plt.grid(True)
  plt.show()
